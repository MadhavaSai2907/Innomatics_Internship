# %%
import numpy as np
import pandas as pd

# %%
ac=pd.read_csv(r'G:\Data Science\Kanav Assignments\Sample EDA\a.csv')
ac.head(1)
##Doubt-path not accepted.placed r infornt.no issues in analysing and manupalting file?
# Out:
#   Unnamed: 0      ID    Salary          DOJ      DOL              Designation  \
# 0      train  203097  420000.0  6/1/12 0:00  present  senior quality engineer
#
#      JobCity Gender           DOB  10percentage          ...            \
# 0  Bangalore      f  2/19/90 0:00          84.3          ...
#
#   ComputerScience  MechanicalEngg  ElectricalEngg TelecomEngg  CivilEngg  \
# 0              -1              -1              -1          -1         -1
#
#    conscientiousness agreeableness extraversion  nueroticism  \
# 0             0.9737        0.8128       0.5269       1.3549
#
#    openess_to_experience
# 0                -0.4455
#
# [1 rows x 39 columns]

# %%
ac.describe(include='all')
# Out:
#        Unnamed: 0            ID        Salary          DOJ      DOL  \
# count        3998  3.998000e+03  3.998000e+03         3998     3998
# unique          1           NaN           NaN           81       67
# top         train           NaN           NaN  7/1/14 0:00  present
# freq         3998           NaN           NaN          199     1875
# mean          NaN  6.637945e+05  3.076998e+05          NaN      NaN
# std           NaN  3.632182e+05  2.127375e+05          NaN      NaN
# min           NaN  1.124400e+04  3.500000e+04          NaN      NaN
# 25%           NaN  3.342842e+05  1.800000e+05          NaN      NaN
# 50%           NaN  6.396000e+05  3.000000e+05          NaN      NaN
# 75%           NaN  9.904800e+05  3.700000e+05          NaN      NaN
# max           NaN  1.298275e+06  4.000000e+06          NaN      NaN
#
#               Designation    JobCity Gender          DOB  10percentage  \
# count                3998       3998   3998         3998   3998.000000
# ...

# %% [markdown]
# # Observation-1

# %%
ac[['10percentage','12percentage','collegeGPA','CollegeTier']][ac['Salary']>ac['Salary'].mean()]
# Out:
#       10percentage  12percentage  collegeGPA  CollegeTier
# 0            84.30         95.80       78.00            2
# 1            85.40         85.00       70.06            2
# 2            85.00         68.20       70.00            2
# 3            85.60         83.60       74.64            1
# 7            92.00         91.00        8.58            1
# 8            90.00         91.20       85.03            1
# 10           88.60         83.70       74.90            2
# 11           81.00         86.00       72.29            1
# 15           69.54         64.43       63.00            2
# 16           85.80         74.80       64.80            2
# 19           79.00         62.20       76.30            2
# 20           91.20         84.63       78.15            2
# 24           88.00         90.00       76.00            2
# 25           86.80         82.80       78.00            2
# 26           90.88         82.50       66.15            2
# ...

# %% [markdown]
# # Observation-2

# %%
sd=ac.groupby('Gender')
sd.head(2)
# Out:
#   Unnamed: 0      ID     Salary          DOJ      DOL  \
# 0      train  203097   420000.0  6/1/12 0:00  present
# 1      train  579905   500000.0  9/1/13 0:00  present
# 2      train  810601   325000.0  6/1/14 0:00  present
# 3      train  267447  1100000.0  7/1/11 0:00  present
#
#                 Designation    JobCity Gender           DOB  10percentage  \
# 0   senior quality engineer  Bangalore      f  2/19/90 0:00          84.3
# 1         assistant manager     Indore      m  10/4/89 0:00          85.4
# 2          systems engineer    Chennai      f   8/3/92 0:00          85.0
# 3  senior software engineer    Gurgaon      m  12/5/89 0:00          85.6
#
#            ...           ComputerScience  MechanicalEngg  ElectricalEngg  \
# 0          ...                        -1              -1              -1
# 1          ...                        -1              -1              -1
# 2          ...                        -1              -1              -1
# ...

# %%
ac['Gender'].value_counts()
# Out:
# m    3041
# f     957
# Name: Gender, dtype: int64

# %%
sd['Salary'].mean()
# Out:
# Gender
# f    294937.304075
# m    311716.211772
# Name: Salary, dtype: float64

# %% [markdown]
# # Obervation-3

# %%
dc=ac.groupby('JobCity')
dc.head(1)
# Out:
#      Unnamed: 0       ID     Salary           DOJ           DOL  \
# 0         train   203097   420000.0   6/1/12 0:00       present
# 1         train   579905   500000.0   9/1/13 0:00       present
# 2         train   810601   325000.0   6/1/14 0:00       present
# 3         train   267447  1100000.0   7/1/11 0:00       present
# 4         train   343523   200000.0   3/1/14 0:00   3/1/15 0:00
# 5         train  1027655   300000.0   6/1/14 0:00       present
# 6         train   947847   300000.0   8/1/14 0:00   5/1/15 0:00
# 8         train   552574   600000.0   7/1/13 0:00       present
# 9         train  1203363   230000.0   7/1/14 0:00       present
# 11        train   190393   450000.0   8/1/11 0:00  10/1/14 0:00
# 15        train   536517   350000.0   8/1/13 0:00       present
# 35        train   942679   350000.0   3/1/14 0:00       present
# 40        train   245887   120000.0   6/1/11 0:00   3/1/12 0:00
# 41        train   955678   145000.0   7/1/14 0:00   9/1/14 0:00
# ...

# %%
dc['Salary'].mean()[(dc['JobCity']=='Hyderabad') & (dc['Gender']=='m')]
# Out:
# 335000.0

# %% [markdown]
# # Observation-4

# %%
lc=ac.loc[(ac['10percentage']>80.0) & (ac['12percentage']>80.0) &(ac['collegeGPA']>75.0),'conscientiousness':'openess_to_experience']
print(lc.mean())

lc
# Out:
# conscientiousness        0.117981
# agreeableness            0.317892
# extraversion            -0.037166
# nueroticism             -0.347883
# openess_to_experience   -0.116553
# dtype: float64
#       conscientiousness  agreeableness  extraversion  nueroticism  \
# 0                0.9737         0.8128        0.5269      1.35490
# 5               -0.3027        -0.6201       -2.2954     -0.74150
# 8               -0.1590         0.5454       -0.6048     -0.74150
# 20              -0.1082         0.9688        0.5269     -0.29020
# 22              -0.4463        -0.6201       -0.6048      0.77980
# 24               0.4155         0.8027        0.1357     -0.99500
# 25               0.0464         1.2028       -0.9245      0.53230
# 30              -0.4173         0.6568       -0.0537     -1.23030
# 32              -0.7335        -0.4536       -1.0659      1.16010
# 39               0.3941         1.2808        0.2366     -2.19980
# ...

# %% [markdown]
# # Observation-5

# %%
ac.loc[ac['CollegeTier']==1,'English':'Quant']
# Out:
#       English  Logical  Quant
# 3         635      585    625
# 7         545      555    590
# 8         615      670    530
# 11        495      605    715
# 32        570      475    295
# 36        380      535    530
# 42        555      560    825
# 64        444      555    695
# 137       535      445    465
# 158       590      555    545
# 163       420      485    545
# 164       625      605    735
# 165       565      475    615
# 166       625      555    625
# 168       530      595    340
# 184       525      525    565
# 193       525      455    465
# 195       580      640    870
# 196       595      605    645
# 198       660      680    765
# 200       655      625    675
# 206       730      610    695
# 214       455      485    605
# 220       660      495    590
# 227       695      625    725
# 229       720      580    645
# 230       640      570    840
# 249       595      520    605
# 268       650      570    750
# 283       370      525    545
# ...
